# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('./trap_positions_181008_CecB-PCPG vesicles- after flushing_1_MMStack_Pos22.ome.tif.csv')

# %%
df
# Out:
#     2.000000000000000000e+00  3.870000000000000000e+02  \
# 0                        3.0                     387.0
# 1                        4.0                     356.0
# 2                        5.0                     356.0
# 3                        6.0                     356.0
# 4                        7.0                     326.0
# 5                        8.0                     326.0
# 6                        9.0                     296.0
# 7                       10.0                     296.0
# 8                       11.0                     295.0
# 9                       12.0                     220.0
# 10                      13.0                     204.0
# 11                      15.0                     143.0
# 12                      16.0                     143.0
# 13                      17.0                     142.0
# 14                      18.0                      55.0
# 15                      19.0                      51.0
# ...
